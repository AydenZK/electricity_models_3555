# %%
import pandas as pd

# %%
df = pd.read_csv("data/wikipedia.csv")
df
# Out:
#      Michael_J._Fox_en.wikipedia.org_all-access_all-agents  12682  20285  \
# 0     List_of_HTTP_status_codes_en.wikipedia.org_all...      8242   8066
# 1     Dolly_Parton_en.wikipedia.org_all-access_all-a...      4167   3817
# 2     Special:Upload_en.wikipedia.org_desktop_all-ag...      8989   6630
# 3     Andy_Warhol_en.wikipedia.org_all-access_all-ag...      6024   6916
# 4     Ronald_Reagan_en.wikipedia.org_desktop_all-agents      5293   5404
# ...                                                 ...       ...    ...
# 4995  Charlotte_Riley_en.wikipedia.org_mobile-web_al...      2445   2444
# 4996  Sigourney_Weaver_en.wikipedia.org_mobile-web_a...      1607   1867
# 4997      Coca-Cola_en.wikipedia.org_desktop_all-agents      2891   2920
# 4998      Thalía_es.wikipedia.org_all-access_all-agents      2112   2416
# 4999        昭和天皇_ja.wikipedia.org_all-access_all-agents      2707   2552
#
#       18601  9535  8248   7298  6464  7114   6300  ...   6071   6065   6269  \
# ...
